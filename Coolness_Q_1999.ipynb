# %%
import numpy as np
import pandas as pd

# %%
data_1999 = pd.read_excel(r'C:\Users\rhomi\Documents\Datasets\Yearly Data\NYTS1999.xlsx')

# %%
#data_1999

# %%
race_sex_age = data_1999[["QN2", "QN5", "QN47"]]

# %%
media_influence = data_1999[["QN60", "QN62"]]

# %%
social_influence = data_1999[["QN40", "QN43", "QN46", "QN47"]]

# %%
awareness = data_1999[["QN44","QN48","QN68"]]

# %%
quitting = data_1999[["QN21", "QN22"]]

# %%
social_circle = data_1999[["QN69","QN71"]]

# %%
socially_cool = data_1999[["QN2", "QN3", "QN5", "QN18", "QN47"]]

# %%
df_1999_socially_cool = data_1999.groupby(['QN2','QN5','QN47']).count()

# %%
df_1999_socially_cool = df_1999_socially_cool[["STUDNTID"]]

# %%
df_1999_socially_cool
# Out:
#     Sex  Race  Coolness_Q  Count
# 0   1.0   1.0         1.0      8
# 1   1.0   1.0         2.0      5
# 2   1.0   1.0         3.0     27
# 3   1.0   1.0         4.0     99
# 4   1.0   2.0         1.0      4
# 5   1.0   2.0         2.0     23
# 6   1.0   2.0         3.0     32
# 7   1.0   2.0         4.0    205
# 8   1.0   3.0         1.0     37
# 9   1.0   3.0         2.0    102
# 10  1.0   3.0         3.0    136
# 11  1.0   3.0         4.0    958
# 12  1.0   4.0         1.0     26
# 13  1.0   4.0         2.0     98
# 14  1.0   4.0         3.0    185
# 15  1.0   4.0         4.0   1092
# 16  1.0   5.0         1.0      6
# 17  1.0   5.0         2.0      4
# 18  1.0   5.0         3.0     16
# 19  1.0   5.0         4.0     57
# 20  1.0   6.0         1.0     74
# 21  1.0   6.0         2.0    217
# 22  1.0   6.0         3.0    633
# 23  1.0   6.0         4.0   3189
# 24  2.0   1.0         1.0     12
# 25  2.0   1.0         2.0      8
# 26  2.0   1.0         3.0     37
# ...

# %%
# Turn Pandas Multi-Index Column headers into actual column headers
# Link -- http://stackoverflow.com/questions/20110170/turn-pandas-multi-index-into-column

df_1999_socially_cool.reset_index(inplace=True)

# %%
#df_1999_socially_cool

# %%
old_names = df_1999_socially_cool.columns.values 
new_names = ['Sex','Race','Coolness_Q','Count']

# %%
old_names
# Out:
# array(['QN2', 'QN5', 'QN47', u'STUDNTID'], dtype=object)

# %%
new_names
# Out:
# ['Sex', 'Race', 'Coolness_Q', 'Count']

# %%
df_1999_socially_cool.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %%
df_1999_socially_cool
# Out:
#     Sex  Race  Coolness_Q  Count
# 0   1.0   1.0         1.0      8
# 1   1.0   1.0         2.0      5
# 2   1.0   1.0         3.0     27
# 3   1.0   1.0         4.0     99
# 4   1.0   2.0         1.0      4
# 5   1.0   2.0         2.0     23
# 6   1.0   2.0         3.0     32
# 7   1.0   2.0         4.0    205
# 8   1.0   3.0         1.0     37
# 9   1.0   3.0         2.0    102
# 10  1.0   3.0         3.0    136
# 11  1.0   3.0         4.0    958
# 12  1.0   4.0         1.0     26
# 13  1.0   4.0         2.0     98
# 14  1.0   4.0         3.0    185
# 15  1.0   4.0         4.0   1092
# 16  1.0   5.0         1.0      6
# 17  1.0   5.0         2.0      4
# 18  1.0   5.0         3.0     16
# 19  1.0   5.0         4.0     57
# 20  1.0   6.0         1.0     74
# 21  1.0   6.0         2.0    217
# 22  1.0   6.0         3.0    633
# 23  1.0   6.0         4.0   3189
# 24  2.0   1.0         1.0     12
# 25  2.0   1.0         2.0      8
# 26  2.0   1.0         3.0     37
# ...

# %%
excel_writer = pd.ExcelWriter(r'C:\Users\rhomi\Documents\Datasets\Yearly Data\socially_cool_1999.xlsx')

df_1999_socially_cool.to_excel(excel_writer)
excel_writer.save()
